# %% [markdown]
# # Import data

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Assign path string to variable
path = r'D:\Docs\Career Foundry\II. Data Immersion\4. Python Fundamentals for Data Analysts\Instacart Basket Analysis - Alina Racu'

# %%
# Import file
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', '4.6 orders_products_combined.pkl'))

# %% [markdown]
# # If-statements

# %% [markdown]
# ## If-statements with user-defined functions

# %%
# Create a subset
df = df_ords_prods_merged[:1000000]

# %%
# Check
df.shape
# Out:
# (1000000, 14)

# %%
# Check
df.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   473747       1             3                  3                 12
# 1   431534       1             5                  4                 15
# 2   550135       1             7                  1                  9
# 3   487368      15            22                  1                 10
# 4   532817      19             7                  4                 17
#
#    days_since_prior_order product_id  add_to_cart_order  reordered  \
# 0                    21.0        196                  1          1
# 1                    28.0        196                  1          1
# 2                    20.0        196                  1          1
# 3                    14.0        196                  1          1
# 4                     6.0        196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %%
# Define a function, categorize rows based on price range
def price_label(row):
    if row["prices"] <= 5:
        return "Low-range product"
    elif (row["prices"] > 5) and (row["prices"] <= 15):
        return "Mid-range product"
    elif row["prices"] > 15:
        return "High-range product"
    else: return "Not enough data"

# %%
# Apply the function
df["price_range"] = df.apply(price_label, axis = 1)
# Out:
# <ipython-input-8-0a7f813ff2cc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["price_range"] = df.apply(price_label, axis = 1)

# %%
# Count values in column "price_range"
df["price_range"].value_counts(dropna = False)
# Out:
# Mid-range product     809441
# Low-range product     182353
# High-range product      8206
# Name: price_range, dtype: int64

# %%
# Check max value in column "prices"
df["prices"].max()
# Out:
# 19.6

# %% [markdown]
# ## If-statements with the loc() function

# %%
# Use different cells for each condition

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged["prices"] <= 15) & (df_ords_prods_merged["prices"] > 5), "price_range_loc"] = "Mid-range product"

# %%
df_ords_prods_merged.loc[df_ords_prods_merged["prices"] <= 5, "price_range_loc"] = "Low-range product"

# %%
# Count values in column "price_range_loc"
df_ords_prods_merged["price_range_loc"].value_counts(dropna = False)
# Out:
# Mid-range product     6739551
# Low-range product     3122612
# High-range product     128743
# Name: price_range_loc, dtype: int64

# %%
# Copy count table to clipboard
df_ords_prods_merged["price_range_loc"].value_counts(dropna = False).to_clipboard()

# %%
# Check
df_ords_prods_merged.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   473747       1             3                  3                 12
# 1   431534       1             5                  4                 15
# 2   550135       1             7                  1                  9
# 3   487368      15            22                  1                 10
# 4   532817      19             7                  4                 17
#
#    days_since_prior_order product_id  add_to_cart_order  reordered  \
# 0                    21.0        196                  1          1
# 1                    28.0        196                  1          1
# 2                    20.0        196                  1          1
# 3                    14.0        196                  1          1
# 4                     6.0        196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc
# ...

# %% [markdown]
# ## If-statements with for-loops

# %%
# Count values in column "order_day_of_the_week"
df_ords_prods_merged["order_day_of_week"].value_counts(dropna = False)
# Out:
# 0    1912844
# 1    1746698
# 6    1384493
# 2    1305496
# 5    1293220
# 3    1183852
# 4    1164303
# Name: order_day_of_week, dtype: int64

# %%
# Create empty list
result = []

# Loop
for value in df_ords_prods_merged["order_day_of_week"]:
    if value  == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("Regularly busy")

# %%
# Print "result" list
result
# Out:
# ['Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Create new column "busiest_day" and set it equal to the "result" list
df_ords_prods_merged["busiest_day"] = result

# %%
# Count values in column "busiest_day"
df_ords_prods_merged["busiest_day"].value_counts(dropna = False)
# Out:
# Regularly busy    6913759
# Busiest day       1912844
# Least busy        1164303
# Name: busiest_day, dtype: int64

# %%
# Copy count table to clipboard
df_ords_prods_merged["busiest_day"].value_counts(dropna = False).to_clipboard()

# %%
# Check
df_ords_prods_merged.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   473747       1             3                  3                 12
# 1   431534       1             5                  4                 15
# 2   550135       1             7                  1                  9
# 3   487368      15            22                  1                 10
# 4   532817      19             7                  4                 17
#
#    days_since_prior_order product_id  add_to_cart_order  reordered  \
# 0                    21.0        196                  1          1
# 1                    28.0        196                  1          1
# 2                    20.0        196                  1          1
# 3                    14.0        196                  1          1
# 4                     6.0        196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# # Task

# %%
# 1. Create new column "busiest_days" and change the logic (two busiest days vs. two slowest days)

# %%
# Create empty list
busiest_days_list = []

# Loop
for value in df_ords_prods_merged["order_day_of_week"]:
    if value  == 0 or value == 1:
        busiest_days_list.append("Busiest days")
    elif value == 4 or value == 3:
        busiest_days_list.append("Slowest days")
    else:
        busiest_days_list.append("Regularly busy")

# %%
# Print "busiest_days_list"
busiest_days_list
# Out:
# ['Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Slowest days',
#  'Regularly busy',
#  'Slowest days',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
# ...

# %%
# Create new column "busiest_days" and set it equal to list "busiest_days_list"
df_ords_prods_merged["busiest_days"] = busiest_days_list

# %%
# Count values in column "busiest_days"
df_ords_prods_merged["busiest_days"].value_counts(dropna = False)
# Out:
# Regularly busy    3983209
# Busiest days      3659542
# Slowest days      2348155
# Name: busiest_days, dtype: int64

# %%
# Copy count table to clipboard
df_ords_prods_merged["busiest_days"].value_counts(dropna = False).to_clipboard()

# %%
# Check
df_ords_prods_merged.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   473747       1             3                  3                 12
# 1   431534       1             5                  4                 15
# 2   550135       1             7                  1                  9
# 3   487368      15            22                  1                 10
# 4   532817      19             7                  4                 17
#
#    days_since_prior_order product_id  add_to_cart_order  reordered  \
# 0                    21.0        196                  1          1
# 1                    28.0        196                  1          1
# 2                    20.0        196                  1          1
# 3                    14.0        196                  1          1
# 4                     6.0        196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
# 2. Create a new column containing these labels called "busiest_period_of_day".

# %%
# Count values in column "order_hour_of_day"
df_ords_prods_merged["order_hour_of_day"].value_counts(dropna = False)
# Out:
# 10    850191
# 11    843355
# 14    829407
# 15    817524
# 13    817363
# 12    807696
# 16    780521
# 9     757617
# 17    645374
# 8     530251
# 18    506821
# 19    387702
# 20    302429
# 7     275937
# 21    245779
# 22    195569
# 23    124688
# 6      91178
# 0      65573
# 1      34903
# 5      27530
# 2      21600
# 4      16225
# 3      15673
# Name: order_hour_of_day, dtype: int64

# %%
# Create empty list
busiest_hours_list = []

# Loop
for value in df_ords_prods_merged["order_hour_of_day"]:
    if value  == 10 or value == 11 or value == 14:
        busiest_hours_list.append("Most orders")
    elif value == 3 or value == 4 or value == 2:
        busiest_hours_list.append("Fewest orders")
    else:
        busiest_hours_list.append("Average orders")

# %%
# Check list "busiest_hours_list"
busiest_hours_list
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
# ...

# %%
# Create new column "busiest_period_of_day" and set it equal to list "busiest_hours_list"
df_ords_prods_merged["busiest_period_of_day"] = busiest_hours_list

# %%
# Count values in column "busiest_period_of_day"
df_ords_prods_merged["busiest_period_of_day"].value_counts(dropna = False)
# Out:
# Average orders    7414455
# Most orders       2522953
# Fewest orders       53498
# Name: busiest_period_of_day, dtype: int64

# %%
# Copy count table to clipboard
df_ords_prods_merged["busiest_period_of_day"].value_counts(dropna = False).to_clipboard()

# %%
# Check
df_ords_prods_merged.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   473747       1             3                  3                 12
# 1   431534       1             5                  4                 15
# 2   550135       1             7                  1                  9
# 3   487368      15            22                  1                 10
# 4   532817      19             7                  4                 17
#
#    days_since_prior_order product_id  add_to_cart_order  reordered  \
# 0                    21.0        196                  1          1
# 1                    28.0        196                  1          1
# 2                    20.0        196                  1          1
# 3                    14.0        196                  1          1
# 4                     6.0        196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# ## Export data

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', '4.7 orders_products_merged_variables.pkl'))
