# %% [markdown]
# # Import data

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Assign path string to variable
path = r'D:\Docs\Career Foundry\II. Data Immersion\4. Python Fundamentals for Data Analysts\Instacart Basket Analysis - Alina Racu'

# %%
# Import file
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', '4.7 orders_products_merged_variables.pkl'))

# %% [markdown]
# # Grouping data

# %%
# Create subset
df = df_ords_prods_merged[:1000000]

# %%
# Check
df.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   473747       1             3                  3                 12
# 1   431534       1             5                  4                 15
# 2   550135       1             7                  1                  9
# 3   487368      15            22                  1                 10
# 4   532817      19             7                  4                 17
#
#    days_since_prior_order product_id  add_to_cart_order  reordered  \
# 0                    21.0        196                  1          1
# 1                    28.0        196                  1          1
# 2                    20.0        196                  1          1
# 3                    14.0        196                  1          1
# 4                     6.0        196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product
#
#       busiest_day  busiest_days busiest_period_of_day
# 0  Regularly busy  Slowest days        Average orders
# 1      Least busy  Slowest days        Average orders
# 2  Regularly busy  Busiest days        Average orders
# 3  Regularly busy  Busiest days           Most orders
# 4      Least busy  Slowest days        Average orders

# %%
# Check
df.shape
# Out:
# (1000000, 18)

# %%
df.groupby('product_name')

# %%
# The output of the groupby() function is not visible, use this function as part of a series of steps

# %% [markdown]
# # Aggregating data with agg() - single aggregation

# %%
# Calculate the mean of the "order_number" column grouped by the "department_id" column
# Step 1: Split the data into groups based on "department_id"
# Step 2: Apply the agg() function to each group to obtain the mean values for the "order_number" column
 
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                16.219468
# 3                14.004000
# 4                18.508363
# 5                 6.000000
# 6                16.933273
# 7                17.313949
# 9                12.664267
# 12               16.603279
# 13               17.374624
# 14               19.132253
# 15               16.983641
# 16               17.594625
# 17               18.338768
# 19               18.791378
# 20               17.535862

# %%
# Alternative using the mean() function
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     16.219468
# 3     14.004000
# 4     18.508363
# 5      6.000000
# 6     16.933273
# 7     17.313949
# 9     12.664267
# 12    16.603279
# 13    17.374624
# 14    19.132253
# 15    16.983641
# 16    17.594625
# 17    18.338768
# 19    18.791378
# 20    17.535862
# Name: order_number, dtype: float64

# %%
# Alternative using the mean() function without brackets
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 1     16.219468
# 3     14.004000
# 4     18.508363
# 5      6.000000
# 6     16.933273
# 7     17.313949
# 9     12.664267
# 12    16.603279
# 13    17.374624
# 14    19.132253
# 15    16.983641
# 16    17.594625
# 17    18.338768
# 19    18.791378
# 20    17.535862
# Name: order_number, dtype: float64

# %% [markdown]
# # Aggregating data with agg() - multiple aggregation

# %%
# # Calculate the mean, min and max of the "order_number" column grouped by the "department_id" column
df.groupby("department_id").agg({"order_number": ["mean", "min", "max"]})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                16.219468   1  99
# 3                14.004000   1  92
# 4                18.508363   1  99
# 5                 6.000000   1  17
# 6                16.933273   1  90
# 7                17.313949   1  99
# 9                12.664267   1  99
# 12               16.603279   1  98
# 13               17.374624   1  99
# 14               19.132253   1  99
# 15               16.983641   1  99
# 16               17.594625   1  99
# 17               18.338768   1  99
# 19               18.791378   1  99
# 20               17.535862   1  99

# %% [markdown]
# # Aggregating data with transform()

# %%
# Create a customer loyalty flag column
# Step 1: Use the transform() function to create a new column containing the maximum frequency of the "order_number" column

# %%
# Create a new column, "max_order" into which to place the results of the aggregation
# Group data in df by "user_id" column
# Transform the "order_number" column by applying the max() function from the NumPy library 
df_ords_prods_merged["max_order"] = df_ords_prods_merged.groupby(["user_id"])["order_number"].transform(np.max)

# %%
# Check
df_ords_prods_merged.head(100)
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    473747       1             3                  3                 12
# 1    431534       1             5                  4                 15
# 2    550135       1             7                  1                  9
# 3    487368      15            22                  1                 10
# 4    532817      19             7                  4                 17
# ..      ...     ...           ...                ...                ...
# 95   260155    2085             9                  3                 16
# 96   575626    2128             2                  4                 15
# 97   687217    2139             4                  0                  9
# 98   889260    2253            16                  5                 10
# 99   535419    2253            19                  4                 15
#
#     days_since_prior_order product_id  add_to_cart_order  reordered  \
# 0                     21.0        196                  1          1
# 1                     28.0        196                  1          1
# 2                     20.0        196                  1          1
# 3                     14.0        196                  1          1
# 4                      6.0        196                  1          1
# ..                     ...        ...                ...        ...
# 95                    20.0        196                  5          1
# 96                     6.0        196                  1          0
# 97                    30.0        196                  2          1
# 98                     0.0        196                  2          1
# 99                     7.0        196                  3          1
#
#    product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0          Soda        77              7     9.0   both  Mid-range product
# 1          Soda        77              7     9.0   both  Mid-range product
# 2          Soda        77              7     9.0   both  Mid-range product
# 3          Soda        77              7     9.0   both  Mid-range product
# 4          Soda        77              7     9.0   both  Mid-range product
# ..          ...       ...            ...     ...    ...                ...
# 95         Soda        77              7     9.0   both  Mid-range product
# 96         Soda        77              7     9.0   both  Mid-range product
# 97         Soda        77              7     9.0   both  Mid-range product
# 98         Soda        77              7     9.0   both  Mid-range product
# 99         Soda        77              7     9.0   both  Mid-range product
#
#        busiest_day    busiest_days busiest_period_of_day  max_order
# 0   Regularly busy    Slowest days        Average orders          7
# 1       Least busy    Slowest days        Average orders          7
# 2   Regularly busy    Busiest days        Average orders          7
# 3   Regularly busy    Busiest days           Most orders         22
# 4       Least busy    Slowest days        Average orders          9
# ..             ...             ...                   ...        ...
# 95  Regularly busy    Slowest days        Average orders          9
# 96      Least busy    Slowest days        Average orders          5
# 97     Busiest day    Busiest days        Average orders          4
# 98  Regularly busy  Regularly busy           Most orders         33
# 99      Least busy    Slowest days        Average orders         33
#
# [100 rows x 19 columns]

# %%
# Tell pandas not to assign any options regarding the maximum number of rows to display (show all 100 rows from previous cell)
pd.options.display.max_rows = None

# %%
# Check
df_ords_prods_merged.head(100)
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    473747       1             3                  3                 12
# 1    431534       1             5                  4                 15
# 2    550135       1             7                  1                  9
# 3    487368      15            22                  1                 10
# 4    532817      19             7                  4                 17
# 5    580568      52             5                  2                 10
# 6    342306      52             9                  1                 11
# 7    944694      52            12                  1                 16
# 8    180919      52            19                  3                  8
# 9    970922      67             2                  1                 15
# 10   596585      67             3                  1                 13
# 11   551869      67            14                  1                  9
# 12   768572      67            16                  4                 10
# 13   150528      67            18                  5                 16
# 14    29758      67            19                  0                 14
# 15   863974      67            22                  1                 11
# 16   499460      82             3                  5                 10
# 17   343588      82            10                  2                 11
# 18   147262      82            18                  1                 13
# 19   681011      98             9                  3                  9
# 20   747431      98            12                  6                 13
# 21   520620     120             1                  3                 11
# 22   276171     195            19                  5                 11
# 23   417035     195            40                  3                 16
# 24   745908     195            57                  4                 11
# 25   858092     420             4                  1                 19
# 26   119314     420             5                  3                 19
# 27   668870     591             2                  1                 13
# 28   981587     626            12                  1                  9
# 29   716308     626            20                  3                 12
# 30   325835     626            85                  1                 17
# 31   490788     642             2                  2                 10
# 32    46887     676             6                  0                 11
# 33   443065     676            10                  5                 18
# 34   296844     680             5                  5                 19
# 35   962470     691            14                  6                 15
# 36   147387     709             4                  0                 21
# 37   231498     793             1                  1                 10
# 38   657712     793             2                  2                 12
# 39    79610     793             5                  3                 12
# 40   212048     992             9                  0                 13
# 41   681310     992            10                  5                 13
# 42    58766     992            11                  5                 13
# 43    88614     992            16                  6                 13
# 44   394447    1031             2                  4                 15
# 45   689328    1126             3                  0                 10
# 46   566383    1126             8                  5                 16
# 47   745438    1126            10                  6                 15
# 48   289494    1137            11                  6                 11
# 49   147278    1137            12                  0                 13
# 50  1038588    1219            16                  1                 11
# 51   827240    1219            19                  1                 11
# 52   305666    1219            21                  5                 11
# 53   512991    1256             1                  1                 10
# 54   402693    1306             6                  6                 10
# 55    61993    1344            14                  4                 10
# 56   901526    1408            18                  1                 10
# 57  1003286    1408            23                  2                 13
# 58   378558    1434             1                  6                 19
# 59   512880    1438             3                  5                  9
# 60   787101    1438             8                  5                 10
# 61   732706    1438            11                  5                  9
# 62   352791    1438            21                  5                  9
# 63   958253    1438            22                  4                 15
# 64   105499    1438            33                  1                 13
# 65    92899    1469             3                  4                 13
# 66   319475    1480             2                  2                 12
# 67   194732    1480            16                  4                 11
# 68   316947    1540             1                  1                 20
# 69   783503    1540            21                  0                 20
# 70   665207    1542            10                  4                 15
# 71   387688    1550             5                  3                 15
# 72   756740    1550            13                  5                 14
# 73   726947    1598             3                  4                 17
# 74   467918    1613            15                  6                 13
# 75  1020683    1680            27                  5                 10
# 76   486609    1680            36                  3                 18
# 77   112979    1680            37                  5                 14
# 78   231329    1723             2                  1                  9
# 79   835467    1726             2                  5                 18
# 80   600015    1755             3                  1                 16
# 81    83211    1774             2                  2                 19
# 82   411022    1774             3                  0                 23
# 83   134686    1774             5                  1                 20
# 84   814433    1776            37                  5                 10
# 85   952725    1776            41                  5                 16
# 86   328145    1821             5                  2                 18
# 87   796675    2050             2                  0                 14
# 88   402193    2050             3                  6                  7
# 89   464724    2050             7                  0                 11
# 90   467519    2057             1                  1                  9
# 91  1034725    2057            10                  1                 16
# 92   588260    2057            32                  2                  9
# 93    44909    2085             1                  1                 13
# 94   493110    2085             3                  0                 17
# 95   260155    2085             9                  3                 16
# 96   575626    2128             2                  4                 15
# 97   687217    2139             4                  0                  9
# 98   889260    2253            16                  5                 10
# 99   535419    2253            19                  4                 15
#
#     days_since_prior_order product_id  add_to_cart_order  reordered  \
# 0                     21.0        196                  1          1
# 1                     28.0        196                  1          1
# 2                     20.0        196                  1          1
# 3                     14.0        196                  1          1
# 4                      6.0        196                  1          1
# 5                      8.0        196                  6          1
# 6                      7.0        196                  5          1
# 7                      6.0        196                  7          1
# 8                      8.0        196                  4          1
# 9                      5.0        196                  2          1
# 10                     7.0        196                  2          1
# 8          Soda        77              7     9.0   both  Mid-range product
# 9          Soda        77              7     9.0   both  Mid-range product
# 10         Soda        77              7     9.0   both  Mid-range product
# 11         Soda        77              7     9.0   both  Mid-range product
# 12         Soda        77              7     9.0   both  Mid-range product
# 13         Soda        77              7     9.0   both  Mid-range product
# 14         Soda        77              7     9.0   both  Mid-range product
# 15         Soda        77              7     9.0   both  Mid-range product
# 16         Soda        77              7     9.0   both  Mid-range product
# 17         Soda        77              7     9.0   both  Mid-range product
# 18         Soda        77              7     9.0   both  Mid-range product
# 19         Soda        77              7     9.0   both  Mid-range product
# 20         Soda        77              7     9.0   both  Mid-range product
# 21         Soda        77              7     9.0   both  Mid-range product
# 22         Soda        77              7     9.0   both  Mid-range product
# 23         Soda        77              7     9.0   both  Mid-range product
# 24         Soda        77              7     9.0   both  Mid-range product
# 25         Soda        77              7     9.0   both  Mid-range product
# 26         Soda        77              7     9.0   both  Mid-range product
# 27         Soda        77              7     9.0   both  Mid-range product
# 28         Soda        77              7     9.0   both  Mid-range product
# 29         Soda        77              7     9.0   both  Mid-range product
# 30         Soda        77              7     9.0   both  Mid-range product
# 31         Soda        77              7     9.0   both  Mid-range product
# 32         Soda        77              7     9.0   both  Mid-range product
# 33         Soda        77              7     9.0   both  Mid-range product
# 34         Soda        77              7     9.0   both  Mid-range product
# 35         Soda        77              7     9.0   both  Mid-range product
# 36         Soda        77              7     9.0   both  Mid-range product
# 37         Soda        77              7     9.0   both  Mid-range product
# 38         Soda        77              7     9.0   both  Mid-range product
# 39         Soda        77              7     9.0   both  Mid-range product
# 40         Soda        77              7     9.0   both  Mid-range product
# 41         Soda        77              7     9.0   both  Mid-range product
# 42         Soda        77              7     9.0   both  Mid-range product
# 43         Soda        77              7     9.0   both  Mid-range product
# 44         Soda        77              7     9.0   both  Mid-range product
# 45         Soda        77              7     9.0   both  Mid-range product
# 46         Soda        77              7     9.0   both  Mid-range product
# 47         Soda        77              7     9.0   both  Mid-range product
# 48         Soda        77              7     9.0   both  Mid-range product
# 49         Soda        77              7     9.0   both  Mid-range product
# 50         Soda        77              7     9.0   both  Mid-range product
# 51         Soda        77              7     9.0   both  Mid-range product
# 52         Soda        77              7     9.0   both  Mid-range product
# 53         Soda        77              7     9.0   both  Mid-range product
# 54         Soda        77              7     9.0   both  Mid-range product
# 55         Soda        77              7     9.0   both  Mid-range product
# 56         Soda        77              7     9.0   both  Mid-range product
# 57         Soda        77              7     9.0   both  Mid-range product
# 58         Soda        77              7     9.0   both  Mid-range product
# 59         Soda        77              7     9.0   both  Mid-range product
# 60         Soda        77              7     9.0   both  Mid-range product
# 61         Soda        77              7     9.0   both  Mid-range product
# 62         Soda        77              7     9.0   both  Mid-range product
# 63         Soda        77              7     9.0   both  Mid-range product
# 64         Soda        77              7     9.0   both  Mid-range product
# 65         Soda        77              7     9.0   both  Mid-range product
# 66         Soda        77              7     9.0   both  Mid-range product
# 67         Soda        77              7     9.0   both  Mid-range product
# 68         Soda        77              7     9.0   both  Mid-range product
# 69         Soda        77              7     9.0   both  Mid-range product
# 70         Soda        77              7     9.0   both  Mid-range product
# 71         Soda        77              7     9.0   both  Mid-range product
# 72         Soda        77              7     9.0   both  Mid-range product
# 73         Soda        77              7     9.0   both  Mid-range product
# 74         Soda        77              7     9.0   both  Mid-range product
# 75         Soda        77              7     9.0   both  Mid-range product
# 76         Soda        77              7     9.0   both  Mid-range product
# 77         Soda        77              7     9.0   both  Mid-range product
# 78         Soda        77              7     9.0   both  Mid-range product
# 79         Soda        77              7     9.0   both  Mid-range product
# 80         Soda        77              7     9.0   both  Mid-range product
# 81         Soda        77              7     9.0   both  Mid-range product
# 82         Soda        77              7     9.0   both  Mid-range product
# 83         Soda        77              7     9.0   both  Mid-range product
# 84         Soda        77              7     9.0   both  Mid-range product
# 85         Soda        77              7     9.0   both  Mid-range product
# 86         Soda        77              7     9.0   both  Mid-range product
# 87         Soda        77              7     9.0   both  Mid-range product
# 88         Soda        77              7     9.0   both  Mid-range product
# 89         Soda        77              7     9.0   both  Mid-range product
# 90         Soda        77              7     9.0   both  Mid-range product
# 91         Soda        77              7     9.0   both  Mid-range product
# 92         Soda        77              7     9.0   both  Mid-range product
# 93         Soda        77              7     9.0   both  Mid-range product
# 94         Soda        77              7     9.0   both  Mid-range product
# 95         Soda        77              7     9.0   both  Mid-range product
# 96         Soda        77              7     9.0   both  Mid-range product
# 97         Soda        77              7     9.0   both  Mid-range product
# 98         Soda        77              7     9.0   both  Mid-range product
# 99         Soda        77              7     9.0   both  Mid-range product
#
#        busiest_day    busiest_days busiest_period_of_day  max_order
# 0   Regularly busy    Slowest days        Average orders          7
# 1       Least busy    Slowest days        Average orders          7
# 2   Regularly busy    Busiest days        Average orders          7
# 3   Regularly busy    Busiest days           Most orders         22
# 4       Least busy    Slowest days        Average orders          9
# 5   Regularly busy  Regularly busy           Most orders         24
# 6   Regularly busy    Busiest days           Most orders         24
# 7   Regularly busy    Busiest days        Average orders         24
# 8   Regularly busy    Slowest days        Average orders         24
# 9   Regularly busy    Busiest days        Average orders         22
# 10  Regularly busy    Busiest days        Average orders         22
# 11  Regularly busy    Busiest days        Average orders         22
# 12      Least busy    Slowest days           Most orders         22
# 13  Regularly busy  Regularly busy        Average orders         22
# 14     Busiest day    Busiest days           Most orders         22
# 15  Regularly busy    Busiest days           Most orders         22
# 16  Regularly busy  Regularly busy           Most orders         18
# 17  Regularly busy  Regularly busy           Most orders         18
# 18  Regularly busy    Busiest days        Average orders         18
# 19  Regularly busy    Slowest days        Average orders         12
# 20  Regularly busy  Regularly busy        Average orders         12
# 21  Regularly busy    Slowest days           Most orders          2
# 22  Regularly busy  Regularly busy           Most orders         57
# 23  Regularly busy    Slowest days        Average orders         57
# 24      Least busy    Slowest days           Most orders         57
# 25  Regularly busy    Busiest days        Average orders         20
# 26  Regularly busy    Slowest days        Average orders         20
# 27  Regularly busy    Busiest days        Average orders          4
# 28  Regularly busy    Busiest days        Average orders         94
# 29  Regularly busy    Slowest days        Average orders         94
# 30  Regularly busy    Busiest days        Average orders         94
# 31  Regularly busy  Regularly busy           Most orders          4
# 32     Busiest day    Busiest days           Most orders         10
# 33  Regularly busy  Regularly busy        Average orders         10
# 34  Regularly busy  Regularly busy        Average orders          5
# 35  Regularly busy  Regularly busy        Average orders         22
# 36     Busiest day    Busiest days        Average orders          4
# 37  Regularly busy    Busiest days           Most orders          5
max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Count values in column "loyalty_flag"
df_ords_prods_merged["loyalty_flag"].value_counts(dropna = False)
# Out:
# Regular customer    4719480
# Loyal customer      2960923
# New customer        2310503
# Name: loyalty_flag, dtype: int64

# %%
# Check 1 column: df["column"]
# Check multiple columns:
df_ords_prods_merged[["user_id", "loyalty_flag", "order_number"]].head(60)
# Out:
#    user_id      loyalty_flag  order_number
# 0        1      New customer             3
# 1        1      New customer             5
# 2        1      New customer             7
# 3       15  Regular customer            22
# 4       19      New customer             7
# 5       52  Regular customer             5
# 6       52  Regular customer             9
# 7       52  Regular customer            12
# 8       52  Regular customer            19
# 9       67  Regular customer             2
# 10      67  Regular customer             3
# 11      67  Regular customer            14
# 12      67  Regular customer            16
# 13      67  Regular customer            18
# 14      67  Regular customer            19
# 15      67  Regular customer            22
# 16      82  Regular customer             3
# 17      82  Regular customer            10
# 18      82  Regular customer            18
# 19      98  Regular customer             9
# 20      98  Regular customer            12
# 21     120      New customer             1
# 22     195    Loyal customer            19
# 23     195    Loyal customer            40
# 24     195    Loyal customer            57
# 25     420  Regular customer             4
# 26     420  Regular customer             5
# 27     591      New customer             2
# 28     626    Loyal customer            12
# 29     626    Loyal customer            20
# 30     626    Loyal customer            85
# 31     642      New customer             2
# 32     676      New customer             6
# 33     676      New customer            10
# 34     680      New customer             5
# 35     691  Regular customer            14
# 36     709      New customer             4
# 37     793      New customer             1
# 38     793      New customer             2
# 39     793      New customer             5
# 40     992  Regular customer             9
# 41     992  Regular customer            10
# 42     992  Regular customer            11
# 43     992  Regular customer            16
# 44    1031      New customer             2
# 45    1126      New customer             3
# 46    1126      New customer             8
# 47    1126      New customer            10
# 48    1137  Regular customer            11
# 49    1137  Regular customer            12
# 50    1219  Regular customer            16
# 51    1219  Regular customer            19
# 52    1219  Regular customer            21
# 53    1256      New customer             1
# 54    1306      New customer             6
# 55    1344  Regular customer            14
# 56    1408  Regular customer            18
# 57    1408  Regular customer            23
# 58    1434      New customer             1
# 59    1438    Loyal customer             3

# %%
# Check
df_ords_prods_merged.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   473747       1             3                  3                 12
# 1   431534       1             5                  4                 15
# 2   550135       1             7                  1                  9
# 3   487368      15            22                  1                 10
# 4   532817      19             7                  4                 17
#
#    days_since_prior_order product_id  add_to_cart_order  reordered  \
# 0                    21.0        196                  1          1
# 1                    28.0        196                  1          1
# 2                    20.0        196                  1          1
# 3                    14.0        196                  1          1
# 4                     6.0        196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product
#
#       busiest_day  busiest_days busiest_period_of_day  max_order  \
# 0  Regularly busy  Slowest days        Average orders          7
# 1      Least busy  Slowest days        Average orders          7
# 2  Regularly busy  Busiest days        Average orders          7
# 3  Regularly busy  Busiest days           Most orders         22
# 4      Least busy  Slowest days        Average orders          9
#
#        loyalty_flag
# 0      New customer
# 1      New customer
# 2      New customer
# 3  Regular customer
# 4      New customer
